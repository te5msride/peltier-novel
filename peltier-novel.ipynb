# %%
#initialize packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
#change to directory
import os
os.chdir('C:\\Users\\trevo\\OneDrive - UNT System\\PhD\\Ta Actuator\\Sensors and Actuators A- Physical\\Novel Thermoactive\\Revisions')
#open excel
lifecycle = pd.read_excel('data_4_30_2023.xlsx',sheet_name="Lifecycle")
temperature = pd.read_excel('data_4_30_2023.xlsx',sheet_name="Temperature")

# %%
#simplify the dataframe to only include the columns we need (Time, 0% Zinc Oxide, 5% Zinc Oxide, 10% Zinc Oxide, 15% Zinc Oxide, 20% Zinc Oxide, 25% Zinc Oxide)

lifecycle = lifecycle[['Time','0% Zinc Oxide','5% Zinc Oxide','10% Zinc Oxide','15% Zinc Oxide','20% Zinc Oxide','25% Zinc Oxide']]

# %%
#Simplify data frame to include only Time, Copper, Zinc, and Eth
temperature = temperature[['Time','Copper','Zinc','Eth']]
#rename columns eth to ethanol
temperature = temperature.rename(columns={'Eth':'Ethanol'})

# %%
#plot time vs percentages of zinc oxide, make colors clearer

plt.plot(lifecycle['Time'],lifecycle['0% Zinc Oxide'],label='0% Zinc Oxide')
plt.plot(lifecycle['Time'],lifecycle['5% Zinc Oxide'],label='5% Zinc Oxide')
plt.plot(lifecycle['Time'],lifecycle['10% Zinc Oxide'],label='10% Zinc Oxide')
plt.plot(lifecycle['Time'],lifecycle['15% Zinc Oxide'],label='15% Zinc Oxide')
plt.plot(lifecycle['Time'],lifecycle['20% Zinc Oxide'],label='20% Zinc Oxide')
plt.plot(lifecycle['Time'],lifecycle['25% Zinc Oxide'],label='25% Zinc Oxide')
plt.xlabel('Time (s)')
plt.ylabel('Novec (% by mass)')
plt.title('Novec Remaining vs Time')
plt.legend()

# %%
#plot the same, but make the colors more clear and make the graph wider

plt.figure(figsize=(10,5))
plt.plot(lifecycle['Time'],lifecycle['0% Zinc Oxide'],label='0% Zinc Oxide')
plt.plot(lifecycle['Time'],lifecycle['5% Zinc Oxide'],label='5% Zinc Oxide')
plt.plot(lifecycle['Time'],lifecycle['10% Zinc Oxide'],label='10% Zinc Oxide')
plt.plot(lifecycle['Time'],lifecycle['15% Zinc Oxide'],label='15% Zinc Oxide')
plt.plot(lifecycle['Time'],lifecycle['20% Zinc Oxide'],label='20% Zinc Oxide')
plt.plot(lifecycle['Time'],lifecycle['25% Zinc Oxide'],label='25% Zinc Oxide')
plt.xlabel('Time (s)')
plt.ylabel('Novec (% by mass)')
plt.title('Novec Remaining vs Time')
plt.legend()

#save as png
plt.savefig('Novec Remaining vs Time.png',dpi=300)

#save as svg
plt.savefig('Novec Remaining vs Time.svg',dpi=300)

# %%
#plot time vs temperature for copper, zinc, and ethanol

plt.plot(temperature['Time'],temperature['Copper'],label='Copper')
plt.plot(temperature['Time'],temperature['Zinc'],label='Zinc')
plt.plot(temperature['Time'],temperature['Ethanol'],label='Ethanol')
plt.xlabel('Time (s)')
plt.ylabel('Temperature (C)')
plt.title('Temperature vs Time')
plt.legend()

#save as png
plt.savefig('Temperature vs Time.png',dpi=300)
#save as svg
plt.savefig('Temperature vs Time.svg',dpi=300)
